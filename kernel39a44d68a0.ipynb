# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
text=["london paris london","paris paris london"]

# %%
cv = CountVectorizer() #object

# %%
count_matrix=cv.fit_transform(text) #count no of text

# %%
print(count_matrix.toarray())

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
similarity_score = cosine_similarity(count_matrix)

# %%
print(similarity_score)

# %%
import numpy as np
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
df=pd.read_csv("../input/movie_dataset.csv")
df.head()

# %%
df.shape

# %%
df.columns

# %%
features=['cast','genres','director','keywords']

# %% [markdown]
#  **create a column in df which combines all features**

# %%
def combine_features(row):
    return (row['keywords']+row['cast']+row['genres']+row['director'])
#apply this to data set
df['combined_features']=df.apply(combine_features,axis=1) #for col(y axis) for x axis it's 0
print('combined_features:',df['combined_features'].head())

# %%
def combine_features(row):
    try:
        return (row['keywords']+row['cast']+row['genres']+row['director'])
#apply this to data set
    except:
        print("error",row)
df['combined_features']=df.apply(combine_features,axis=1) #for col(y axis) for x axis it's 0
print('combined_features:',df['combined_features'].head())

# %%
for feature in features:
    df[feature]=df[feature].fillna("")
def combine_features(row):
    try:
        return (row['keywords']+row['cast']+row['genres']+row['director'])
#apply this to data set
    except:
        print("error",row)
df['combined_features']=df.apply(combine_features,axis=1) #for col(y axis) for x axis it's 0
print('combined_features:',df['combined_features'].head()) #new col name

# %% [markdown]
# ## create count matrix from this combined column

# %%
cv=CountVectorizer()
count_matrix=cv.fit_transform(df['combined_features'])

# %%
cosine_sim=cosine_similarity(count_matrix)
movie_user_likes='Avatar'

# %%
##helper function
def get_title_from_index(index):
    return df[df.index==index]['title'].values[0]
def get_index_from_title(title):
    return df[df.title==title]['index'].values[0]

# %% [markdown]
# ## get index of the movie from it's title

# %%
movie_index=get_index_from_title(movie_user_likes)
similar_movies=list(enumerate(cosine_sim[movie_index]))
sorted_similar_movies= sorted(similar_movies,key=lambda x:[x],reverse=True)[1:]

# %% [markdown]
# ## print title of first 50 movies

# %%
i=0
for pictures in sorted_similar_movies:
    print(get_title_from_index(pictures[0]))
    i=i+1
    if(i>50):
        break
